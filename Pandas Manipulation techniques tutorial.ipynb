# %%
import pandas as pd

# %%
A = pd.read_csv(r'C:\Users\Lenono\Desktop\book1.csv')

# %%
B= pd.read_csv(r'C:\Users\Lenono\Desktop\state-areas.csv')

# %%
columns= ['state', 'ages', 'year' , 'population']

# %%
C= pd.read_csv(r'C:\Users\Lenono\Desktop\state data.csv')

# %%
C.set_index('state/region' , inplace= True)

# %%
A
# Out:
#                    state abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# ...

# %%
B
# Out:
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# 8                Florida          65758
# 9                Georgia          59441
# 10                Hawaii          10932
# 11                 Idaho          83574
# 12              Illinois          57918
# 13               Indiana          36420
# 14                  Iowa          56276
# 15                Kansas          82282
# 16              Kentucky          40411
# 17             Louisiana          51843
# 18                 Maine          35387
# 19              Maryland          12407
# 20         Massachusetts          10555
# 21              Michigan          96810
# ...

# %%
C
# Out:
#                  ages  year   population
# state/region
# AL            under18  2012    1117489.0
# AL              total  2012    4817528.0
# AL            under18  2010    1130966.0
# AL              total  2010    4785570.0
# AL            under18  2011    1125763.0
# ...               ...   ...          ...
# USA             total  2010  309326295.0
# USA           under18  2011   73902222.0
# USA             total  2011  311582564.0
# USA           under18  2012   73708179.0
# USA             total  2012  313873685.0
#
# [2544 rows x 3 columns]

# %%
pd.merge(A, B , how='right' , on='state')
# Out:
#                    state abbreviation  area (sq. mi)
# 0                Alabama           AL          52423
# 1                 Alaska           AK         656425
# 2                Arizona           AZ         114006
# 3               Arkansas           AR          53182
# 4             California           CA         163707
# 5               Colorado           CO         104100
# 6            Connecticut           CT           5544
# 7               Delaware           DE           1954
# 8                Florida           FL          65758
# 9                Georgia           GA          59441
# 10                Hawaii           HI          10932
# 11                 Idaho           ID          83574
# 12              Illinois           IL          57918
# 13               Indiana           IN          36420
# 14                  Iowa           IA          56276
# 15                Kansas           KS          82282
# 16              Kentucky           KY          40411
# ...

# %%
C.fillna(0)
# Out:
#                  ages  year   population
# state/region
# AL            under18  2012    1117489.0
# AL              total  2012    4817528.0
# AL            under18  2010    1130966.0
# AL              total  2010    4785570.0
# AL            under18  2011    1125763.0
# ...               ...   ...          ...
# USA             total  2010  309326295.0
# USA           under18  2011   73902222.0
# USA             total  2011  311582564.0
# USA           under18  2012   73708179.0
# USA             total  2012  313873685.0
#
# [2544 rows x 3 columns]

# %%
C.dtypes
# Out:
# ages           object
# year            int64
# population    float64
# dtype: object

# %%
grouped= C.groupby('ages')

# %%
grouped.population.describe()
# Out:
#           count          mean           std       min        25%        50%  \
# ages
# total    1262.0  1.088161e+07  3.877163e+07  453690.0  1573433.0  3855132.0
# under18  1262.0  2.729506e+06  9.714606e+06  101309.0   390643.0   996839.0
#
#                 75%          max
# ages
# total    6587579.75  316128839.0
# under18  1609651.50   74134167.0

# %%
nobel = pd.read_csv(r'C:\Users\Lenono\Desktop\complete.csv')

# %%
nobel.head().T
# Out:
#                                                                             0  \
# awardYear                                                                2001
# category                                                    Economic Sciences
# categoryFullName            The Sveriges Riksbank Prize in Economic Scienc...
# sortOrder                                                                   2
# portion                                                                   1/3
# prizeAmount                                                          10000000
# prizeAmountAdjusted                                                  12295082
# dateAwarded                                                        2001-10-10
# prizeStatus                                                          received
# motivation                  for their analyses of markets with asymmetric ...
# categoryTopMotivation                                                     NaN
# ...

# %%
nobel.dropna(axis=1)
# Out:
#      awardYear           category  \
# 0         2001  Economic Sciences
# 1         1975            Physics
# 2         2004          Chemistry
# 3         1982          Chemistry
# 4         1979            Physics
# ..         ...                ...
# 945       1972            Physics
# 946       1954          Chemistry
# 947       1911          Chemistry
# 948       1981              Peace
# 949       1963              Peace
#
#                                       categoryFullName  sortOrder portion  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...          2     1/3
# 1                           The Nobel Prize in Physics          1     1/3
# 2                         The Nobel Prize in Chemistry          1     1/3
# 3                         The Nobel Prize in Chemistry          1       1
# 4                           The Nobel Prize in Physics          2     1/3
# ..                                                 ...        ...     ...
# ...

# %%
nobel.head().T
# Out:
#                                                                             0  \
# awardYear                                                                2001
# category                                                    Economic Sciences
# categoryFullName            The Sveriges Riksbank Prize in Economic Scienc...
# sortOrder                                                                   2
# portion                                                                   1/3
# prizeAmount                                                          10000000
# prizeAmountAdjusted                                                  12295082
# dateAwarded                                               2001-10-10 00:00:00
# prizeStatus                                                          received
# motivation                  for their analyses of markets with asymmetric ...
# categoryTopMotivation                                                     NaN
# ...

# %%
from datetime import datetime
nobel['dateAwarded'] = pd.to_datetime(nobel['dateAwarded'])
